# %%
# If running in a fresh kernel, install missing deps
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "SQLAlchemy", "psycopg2-binary", "python-dotenv"], check=False)
# Out:
# Requirement already satisfied: SQLAlchemy in /home/ubuntias/Data Analyics -- Uber/venv/lib/python3.12/site-packages (2.0.43)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: greenlet>=1 in /home/ubuntias/Data Analyics -- Uber/venv/lib/python3.12/site-packages (from SQLAlchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/ubuntias/Data Analyics -- Uber/venv/lib/python3.12/site-packages (from SQLAlchemy) (4.15.0)
# Downloading psycopg2_binary-2.9.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 24.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import subprocess
import sys

# %%
import sqlalchemy as sa
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Date, Time, Text
import pandas as pd
import os
import psycopg2
from dotenv import load_dotenv

load_dotenv()
pg_user = os.getenv("PG_USER", "root")
pg_password = os.getenv("PG_PASSWORD", "practice")
pg_host = os.getenv("PG_HOST", "127.0.0.1")
pg_port = os.getenv("PG_PORT", "5432")
pg_db = os.getenv("PG_DB", "uberda")

engine = create_engine(f"postgresql+psycopg2://{pg_user}:{pg_password}@{pg_host}:{pg_port}/{pg_db}", echo=True)

try:
    with engine.connect() as conn:
        result = conn.execute(sa.text("SELECT 1"))
        print("Database connection successful!")
except Exception as e:
    print(f"Database connection failed: {e}")
# Out:
# 2025-09-24 02:45:43,171 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-09-24 02:45:43,171 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-24 02:45:43,174 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-09-24 02:45:43,174 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-24 02:45:43,176 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-09-24 02:45:43,177 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-09-24 02:45:43,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-24 02:45:43,179 INFO sqlalchemy.engine.Engine SELECT 1
# 2025-09-24 02:45:43,179 INFO sqlalchemy.engine.Engine [generated in 0.00105s] {}
# Database connection successful!
# 2025-09-24 02:45:43,180 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
metadata = MetaData()

uber_bookings = Table(
    'uber_bookings',
    metadata,
    Column('id', Integer, primary_key=True, autoincrement=True),
    Column('date', Date, nullable=False),
    Column('time', Time, nullable=False),
    Column('booking_id', String(50), nullable=False, unique=True),
    Column('booking_status', String(50), nullable=False),
    Column('customer_id', String(50), nullable=False),
    Column('vehicle_type', String(50), nullable=False),
    Column('payment_method', String(50), nullable=True)
)

print("Table schema defined:")
print(f"Table name: {uber_bookings.name}")
print("Columns:")
for column in uber_bookings.columns:
    print(f"  - {column.name}: {column.type}")
# Out:
# Table schema defined:
# Table name: uber_bookings
# Columns:
#   - id: INTEGER
#   - date: DATE
#   - time: TIME
#   - booking_id: VARCHAR(50)
#   - booking_status: VARCHAR(50)
#   - customer_id: VARCHAR(50)
#   - vehicle_type: VARCHAR(50)
#   - payment_method: VARCHAR(50)

# %%
try:
    metadata.create_all(engine)
    print("Table 'uber_bookings' created successfully!")
except Exception as e:
    print(f"Error creating table: {e}")
    if "already exists" in str(e).lower():
        print("Table already exists, continuing...")
# Out:
# 2025-09-24 02:45:53,062 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-24 02:45:53,065 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-09-24 02:45:53,066 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {'table_name': 'uber_bookings', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-09-24 02:45:53,072 INFO sqlalchemy.engine.Engine
# CREATE TABLE uber_bookings (
# 	id SERIAL NOT NULL,
# 	date DATE NOT NULL,
# 	time TIME WITHOUT TIME ZONE NOT NULL,
# 	booking_id VARCHAR(50) NOT NULL,
# 	booking_status VARCHAR(50) NOT NULL,
# 	customer_id VARCHAR(50) NOT NULL,
# 	vehicle_type VARCHAR(50) NOT NULL,
# 	payment_method VARCHAR(50),
# 	PRIMARY KEY (id),
# 	UNIQUE (booking_id)
# )
#
#
# 2025-09-24 02:45:53,072 INFO sqlalchemy.engine.Engine [no key 0.00059s] {}
# 2025-09-24 02:45:53,098 INFO sqlalchemy.engine.Engine COMMIT
# Table 'uber_bookings' created successfully!

# %%
# Read the CSV file from env var with default
from dotenv import load_dotenv
load_dotenv()
csv_path = os.getenv("CSV_PATH", "./data/cleaned_up_pandas.csv")

print(f"Reading CSV file: {csv_path}")
print(f"File exists: {os.path.exists(csv_path)}")

# Read the CSV with proper data types
df = pd.read_csv(csv_path)

print("CSV loaded successfully!")
print(f"Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print("First few rows:")
print(df.head())
# Out:
# Reading CSV file: ../data/cleaned_up_pandas.csv
# File exists: True
# CSV loaded successfully!
# Shape: (150000, 7)
# Columns: ['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID', 'Vehicle Type', 'Payment Method']
# First few rows:
#          Date      Time    Booking ID       Booking Status   Customer ID  \
# 0  2024-01-01  00:19:34  "CNR4352144"            Completed  "CID8362794"
# 1  2024-01-01  01:35:18  "CNR9147645"            Completed  "CID8300238"
# 2  2024-01-01  01:37:50  "CNR1009222"  Cancelled by Driver  "CID2030746"
# 3  2024-01-01  01:48:03  "CNR2740479"  Cancelled by Driver  "CID3231181"
# 4  2024-01-01  01:49:56  "CNR7650148"  Cancelled by Driver  "CID3381661"
#
#   Vehicle Type Payment Method
# 0         bike           Cash
# 1      go mini    Uber Wallet
# 2     go sedan            NaN
# 3         auto            NaN
# 4     go sedan            NaN

# %%
df_clean = df.copy()


df_clean['Booking ID'] = df_clean['Booking ID'].str.replace('"', '')
df_clean['Customer ID'] = df_clean['Customer ID'].str.replace('"', '')


df_clean['Date'] = pd.to_datetime(df_clean['Date']).dt.date
df_clean['Time'] = pd.to_datetime(df_clean['Time'], format='%H:%M:%S').dt.time


df_clean['Payment Method'] = df_clean['Payment Method'].fillna('')


df_clean = df_clean.rename(columns={
    'Date': 'date',
    'Time': 'time', 
    'Booking ID': 'booking_id',
    'Booking Status': 'booking_status',
    'Customer ID': 'customer_id',
    'Vehicle Type': 'vehicle_type',
    'Payment Method': 'payment_method'
})

print(df_clean.head())
print(f"Data types:")
print(df_clean.dtypes)
# Out:
#          date      time  booking_id       booking_status customer_id  \
# 0  2024-01-01  00:19:34  CNR4352144            Completed  CID8362794
# 1  2024-01-01  01:35:18  CNR9147645            Completed  CID8300238
# 2  2024-01-01  01:37:50  CNR1009222  Cancelled by Driver  CID2030746
# 3  2024-01-01  01:48:03  CNR2740479  Cancelled by Driver  CID3231181
# 4  2024-01-01  01:49:56  CNR7650148  Cancelled by Driver  CID3381661
#
#   vehicle_type payment_method
# 0         bike           Cash
# 1      go mini    Uber Wallet
# 2     go sedan
# 3         auto
# 4     go sedan
# Data types:
# date              object
# time              object
# booking_id        object
# booking_status    object
# customer_id       object
# vehicle_type      object
# payment_method    object
# dtype: object

# %%
try:
    with engine.connect() as conn:
        # Check if table has any data
        result = conn.execute(sa.text("SELECT COUNT(*) FROM uber_bookings"))
        count = result.scalar()
        print(f"Current records in database: {count}")
        
        # Non-interactive: clear if CLEAR_EXISTING=y in env
        clear_flag = os.getenv("CLEAR_EXISTING", "n").lower() == "y"
        if count > 0 and clear_flag:
            print("Clearing existing data due to CLEAR_EXISTING=y ...")
            conn.execute(sa.text("DELETE FROM uber_bookings"))
            conn.commit()
            print("Existing data cleared!")
        elif count > 0:
            print("Keeping existing data. New data will be inserted (duplicates skipped).")
                
except Exception as e:
    print(f"Error checking database: {e}")
# Out:
# 2025-09-24 02:45:53,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-24 02:45:53,722 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM uber_bookings
# 2025-09-24 02:45:53,722 INFO sqlalchemy.engine.Engine [generated in 0.00127s] {}
# Current records in database: 0
# 2025-09-24 02:45:53,725 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Insert data into PostgreSQL database
print("Inserting data into PostgreSQL database...")

data_to_insert = df_clean.to_dict('records')

batch_size = 1000
total_records = len(data_to_insert)
inserted_count = 0
skipped_count = 0

print(f"Total records to insert: {total_records}")
print(f"Processing in batches of {batch_size}...")

try:
    with engine.connect() as conn:
        for i in range(0, total_records, batch_size):
            batch = data_to_insert[i:i + batch_size]
            
            try:
                conn.execute(
                    uber_bookings.insert().on_conflict_do_nothing(),
                    batch
                )
                conn.commit()
                inserted_count += len(batch)
                
                if (i // batch_size + 1) % 10 == 0:  # Progress every 10 batches
                    print(f"Processed {inserted_count}/{total_records} records...")
                    
            except Exception as e:
                print(f"Batch {i//batch_size + 1} had issues: {e}")
                for record in batch:
                    try:
                        conn.execute(
                            uber_bookings.insert().on_conflict_do_nothing(),
                            record
                        )
                        inserted_count += 1
                    except:
                        skipped_count += 1
                conn.commit()
                
    print(f"Data insertion completed!")
    print(f"Successfully inserted: {inserted_count} records")
    print(f"⏭Skipped (duplicates): {skipped_count} records")
    
except Exception as e:
    print(f"Error during data insertion: {e}")
# Out:
# Inserting data into PostgreSQL database...
# Total records to insert: 150000
# Processing in batches of 1000...
# Batch 1 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 2 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 3 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 4 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 5 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 6 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 7 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 8 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 9 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 10 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 11 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 12 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 13 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 14 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 15 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 16 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 17 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 18 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 19 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 20 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 21 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 22 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 23 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 24 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 25 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 26 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 27 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 28 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 29 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 30 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 31 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 32 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 33 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 34 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 35 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 36 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 37 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 38 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 39 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 40 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 41 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 42 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 43 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 44 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 45 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 46 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 47 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 48 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 49 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 50 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 51 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 52 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 53 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 54 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 55 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 56 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 57 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 58 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 59 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 60 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 61 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 62 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 63 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 64 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 65 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 66 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 67 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 68 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 69 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 70 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 71 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 72 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 73 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 74 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 75 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 76 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 77 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 78 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 79 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 80 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 81 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 82 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 83 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 84 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 85 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 86 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 87 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 88 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 89 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 90 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 91 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 92 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 93 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 94 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 95 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 96 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 97 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 98 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 99 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 100 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 101 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 102 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 103 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 104 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 105 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 106 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 107 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 108 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 109 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 110 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 111 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 112 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 113 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 114 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 115 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 116 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 117 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 118 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 119 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 120 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 121 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 122 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 123 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 124 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 125 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 126 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 127 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 128 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 129 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 130 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 131 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 132 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 133 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 134 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 135 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 136 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 137 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 138 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 139 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 140 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 141 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 142 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 143 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 144 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 145 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 146 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 147 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 148 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 149 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Batch 150 had issues: 'Insert' object has no attribute 'on_conflict_do_nothing'
# Data insertion completed!
# Successfully inserted: 0 records
# ⏭Skipped (duplicates): 150000 records

# %%
try:
    with engine.connect() as conn:
        # Get total count
        result = conn.execute(sa.text("SELECT COUNT(*) FROM uber_bookings"))
        total_count = result.scalar()
        print(f"Total records in database: {total_count}")
        
        # Get sample data
        result = conn.execute(sa.text("SELECT * FROM uber_bookings LIMIT 5"))
        sample_data = result.fetchall()
        print(f"Sample data:")
        for row in sample_data:
            print(f"  {row}")
            
        result = conn.execute(sa.text("""
            SELECT 
                booking_status,
                COUNT(*) as count
            FROM uber_bookings 
            GROUP BY booking_status 
            ORDER BY count DESC
        """))
        status_stats = result.fetchall()
        print(f"Booking status distribution:")
        for status, count in status_stats:
            print(f"  {status}: {count}")
            
        result = conn.execute(sa.text("""
            SELECT 
                vehicle_type,
                COUNT(*) as count
            FROM uber_bookings 
            GROUP BY vehicle_type 
            ORDER BY count DESC
        """))
        vehicle_stats = result.fetchall()
        print(f"Vehicle type distribution:")
        for vehicle, count in vehicle_stats:
            print(f"  {vehicle}: {count}")
            
except Exception as e:
    print(f"Error verifying data: {e}")
# Out:
# 2025-09-24 02:45:54,540 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-24 02:45:54,541 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM uber_bookings
# 2025-09-24 02:45:54,542 INFO sqlalchemy.engine.Engine [cached since 0.8205s ago] {}
# Total records in database: 0
# 2025-09-24 02:45:54,543 INFO sqlalchemy.engine.Engine SELECT * FROM uber_bookings LIMIT 5
# 2025-09-24 02:45:54,543 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# Sample data:
# 2025-09-24 02:45:54,544 INFO sqlalchemy.engine.Engine
#             SELECT
#                 booking_status,
#                 COUNT(*) as count
#             FROM uber_bookings
#             GROUP BY booking_status
#             ORDER BY count DESC
#
# 2025-09-24 02:45:54,545 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# Booking status distribution:
# 2025-09-24 02:45:54,546 INFO sqlalchemy.engine.Engine
#             SELECT
#                 vehicle_type,
#                 COUNT(*) as count
#             FROM uber_bookings
#             GROUP BY vehicle_type
#             ORDER BY count DESC
#
# 2025-09-24 02:45:54,546 INFO sqlalchemy.engine.Engine [generated in 0.00032s] {}
# Vehicle type distribution:
# 2025-09-24 02:45:54,547 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Postgres upsert insert using SQLAlchemy dialect
from sqlalchemy.dialects.postgresql import insert as pg_insert

batch_size = 1000
rows = df_clean.to_dict('records')

print("Writing with ON CONFLICT DO NOTHING on booking_id...")
written = 0
skipped = 0

with engine.begin() as conn:  # transactional
    for i in range(0, len(rows), batch_size):
        batch = rows[i:i+batch_size]
        stmt = pg_insert(uber_bookings).values(batch)
        stmt = stmt.on_conflict_do_nothing(index_elements=[uber_bookings.c.booking_id])
        res = conn.execute(stmt)
        written += res.rowcount or 0

print(f"done. inserted={written} (skipped duplicates shown by 0 rowcount)")

# %%
try:
    with engine.connect() as conn:
        # Create indexes on commonly queried columns
        indexes = [
            "CREATE INDEX IF NOT EXISTS idx_booking_date ON uber_bookings(date)",
            "CREATE INDEX IF NOT EXISTS idx_booking_status ON uber_bookings(booking_status)",
            "CREATE INDEX IF NOT EXISTS idx_vehicle_type ON uber_bookings(vehicle_type)",
            "CREATE INDEX IF NOT EXISTS idx_customer_id ON uber_bookings(customer_id)",
            "CREATE INDEX IF NOT EXISTS idx_payment_method ON uber_bookings(payment_method)",
            "CREATE INDEX IF NOT EXISTS idx_date_time ON uber_bookings(date, time)"
        ]
        
        for index_sql in indexes:
            try:
                conn.execute(sa.text(index_sql))
                print(f"Created index: {index_sql.split()[-1]}")
            except Exception as e:
                print(f"Index creation warning: {e}")
        
        conn.commit()
        print("All indexes created successfully!")
        
except Exception as e:
    print(f"Error creating indexes: {e}")
# Out:
# 2025-09-24 02:45:54,553 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-09-24 02:45:54,554 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_booking_date ON uber_bookings(date)
# 2025-09-24 02:45:54,555 INFO sqlalchemy.engine.Engine [generated in 0.00121s] {}
# Created index: uber_bookings(date)
# 2025-09-24 02:45:54,557 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_booking_status ON uber_bookings(booking_status)
# 2025-09-24 02:45:54,558 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {}
# Created index: uber_bookings(booking_status)
# 2025-09-24 02:45:54,561 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_vehicle_type ON uber_bookings(vehicle_type)
# 2025-09-24 02:45:54,562 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# Created index: uber_bookings(vehicle_type)
# 2025-09-24 02:45:54,564 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_customer_id ON uber_bookings(customer_id)
# 2025-09-24 02:45:54,564 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# Created index: uber_bookings(customer_id)
# 2025-09-24 02:45:54,567 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_payment_method ON uber_bookings(payment_method)
# 2025-09-24 02:45:54,567 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# Created index: uber_bookings(payment_method)
# 2025-09-24 02:45:54,570 INFO sqlalchemy.engine.Engine CREATE INDEX IF NOT EXISTS idx_date_time ON uber_bookings(date, time)
# 2025-09-24 02:45:54,570 INFO sqlalchemy.engine.Engine [generated in 0.00059s] {}
# Created index: time)
# 2025-09-24 02:45:54,573 INFO sqlalchemy.engine.Engine COMMIT
# All indexes created successfully!

# %% [markdown]
# ## Basic Queries
# ```sql
# -- Get total number of bookings
# SELECT COUNT(*) FROM uber_bookings;
#
# -- Get bookings by status
# SELECT booking_status, COUNT(*) as count
# FROM uber_bookings
# GROUP BY booking_status
# ORDER BY count DESC;
#
# -- Get bookings by vehicle type
# SELECT vehicle_type, COUNT(*) as count
# FROM uber_bookings
# GROUP BY vehicle_type
# ORDER BY count DESC;
# ```
#
# ## Time-based Analysis
# ```sql
# -- Bookings per hour of day
# SELECT EXTRACT(hour FROM time) as hour, COUNT(*) as bookings
# FROM uber_bookings
# GROUP BY hour
# ORDER BY hour;
#
# -- Bookings per day of week
# SELECT EXTRACT(dow FROM date) as weekday, COUNT(*) as bookings
# FROM uber_bookings
# GROUP BY weekday
# ORDER BY weekday;
#
# -- Bookings per month
# SELECT EXTRACT(year FROM date) as year,
#        EXTRACT(month FROM date) as month,
#        COUNT(*) as bookings
# FROM uber_bookings
# GROUP BY year, month
# ORDER BY year, month;
# ```
#
# ## Customer Analysis
# ```sql
# -- Top customers by booking count
# SELECT customer_id, COUNT(*) as total_bookings
# FROM uber_bookings
# GROUP BY customer_id
# ORDER BY total_bookings DESC
# LIMIT 10;
#
# -- Payment method preferences
# SELECT payment_method, COUNT(*) as count
# FROM uber_bookings
# WHERE payment_method != ''
# GROUP BY payment_method
# ORDER BY count DESC;
# ```
